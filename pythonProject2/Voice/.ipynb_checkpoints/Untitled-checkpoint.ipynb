# %%
# !pip install -r requirement.txt
# Out:
# Requirement already satisfied: absl-py in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 1)) (1.3.0)
# Requirement already satisfied: astor in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 2)) (0.8.1)
# Requirement already satisfied: backcall in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 3)) (0.2.0)
# Requirement already satisfied: decorator in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 4)) (5.1.1)
# Requirement already satisfied: gast in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 5)) (0.4.0)
# Requirement already satisfied: google-pasta in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 6)) (0.2.0)
# Requirement already satisfied: grpcio in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 7)) (1.42.0)
# Requirement already satisfied: h5py in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 8)) (3.6.0)
# Requirement already satisfied: ipython in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 9)) (8.2.0)
# Requirement already satisfied: ipython-genutils in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 10)) (0.2.0)
# Requirement already satisfied: jedi in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 11)) (0.18.1)
# Requirement already satisfied: Keras in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 12)) (2.10.0)
# Requirement already satisfied: Keras-Applications in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 13)) (1.0.8)
# Requirement already satisfied: Keras-Preprocessing in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 14)) (1.1.2)
# Requirement already satisfied: Markdown in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 15)) (3.3.4)
# Requirement already satisfied: numpy in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 16)) (1.21.5)
# Requirement already satisfied: opencv-python in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 17)) (4.6.0.66)
# Requirement already satisfied: parso in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 18)) (0.8.3)
# Requirement already satisfied: pexpect in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 19)) (4.8.0)
# Requirement already satisfied: pickleshare in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 20)) (0.7.5)
# Requirement already satisfied: prompt-toolkit in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 21)) (3.0.20)
# Requirement already satisfied: protobuf in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 22)) (3.19.1)
# Requirement already satisfied: ptyprocess in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 23)) (0.7.0)
# Requirement already satisfied: PyAudio in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 24)) (0.2.12)
# Requirement already satisfied: Pygments in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 25)) (2.11.2)
# Requirement already satisfied: python-speech-features in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 26)) (0.6)
# Requirement already satisfied: PyYAML in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 27)) (6.0)
# Requirement already satisfied: scikit-learn in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 28)) (1.0.2)
# Requirement already satisfied: scipy in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 29)) (1.7.3)
# Requirement already satisfied: six in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 30)) (1.16.0)
# Requirement already satisfied: tensorboard in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 31)) (2.10.1)
# Requirement already satisfied: tensorflow in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 32)) (2.10.0)
# Requirement already satisfied: tensorflow-estimator in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 33)) (2.10.0)
# Requirement already satisfied: termcolor in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 34)) (2.1.0)
# Requirement already satisfied: traitlets in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 35)) (5.1.1)
# Requirement already satisfied: Wave in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 36)) (0.0.2)
# Requirement already satisfied: wcwidth in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 37)) (0.2.5)
# Requirement already satisfied: Werkzeug in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 38)) (2.0.3)
# Requirement already satisfied: wrapt in c:\users\wwwsh\anaconda3\lib\site-packages (from -r requirement.txt (line 39)) (1.12.1)
# Requirement already satisfied: stack-data in c:\users\wwwsh\anaconda3\lib\site-packages (from ipython->-r requirement.txt (line 9)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in c:\users\wwwsh\anaconda3\lib\site-packages (from ipython->-r requirement.txt (line 9)) (0.1.2)
# Requirement already satisfied: setuptools>=18.5 in c:\users\wwwsh\anaconda3\lib\site-packages (from ipython->-r requirement.txt (line 9)) (61.2.0)
# Requirement already satisfied: colorama in c:\users\wwwsh\anaconda3\lib\site-packages (from ipython->-r requirement.txt (line 9)) (0.4.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\wwwsh\anaconda3\lib\site-packages (from scikit-learn->-r requirement.txt (line 28)) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in c:\users\wwwsh\anaconda3\lib\site-packages (from scikit-learn->-r requirement.txt (line 28)) (1.1.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\wwwsh\anaconda3\lib\site-packages (from tensorboard->-r requirement.txt (line 31)) (0.4.6)
# Requirement already satisfied: wheel>=0.26 in c:\users\wwwsh\anaconda3\lib\site-packages (from tensorboard->-r requirement.txt (line 31)) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\wwwsh\anaconda3\lib\site-packages (from tensorboard->-r requirement.txt (line 31)) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\wwwsh\anaconda3\lib\site-packages (from tensorboard->-r requirement.txt (line 31)) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\wwwsh\anaconda3\lib\site-packages (from tensorboard->-r requirement.txt (line 31)) (2.27.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\wwwsh\anaconda3\lib\site-packages (from tensorboard->-r requirement.txt (line 31)) (1.33.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\wwwsh\anaconda3\lib\site-packages (from tensorflow->-r requirement.txt (line 32)) (22.10.26)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\wwwsh\anaconda3\lib\site-packages (from tensorflow->-r requirement.txt (line 32)) (0.27.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\wwwsh\anaconda3\lib\site-packages (from tensorflow->-r requirement.txt (line 32)) (1.6.3)
# Requirement already satisfied: packaging in c:\users\wwwsh\anaconda3\lib\site-packages (from tensorflow->-r requirement.txt (line 32)) (21.3)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\wwwsh\anaconda3\lib\site-packages (from tensorflow->-r requirement.txt (line 32)) (3.3.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\wwwsh\anaconda3\lib\site-packages (from tensorflow->-r requirement.txt (line 32)) (14.0.6)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\wwwsh\anaconda3\lib\site-packages (from tensorflow->-r requirement.txt (line 32)) (4.1.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\wwwsh\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirement.txt (line 31)) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\wwwsh\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirement.txt (line 31)) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\wwwsh\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard->-r requirement.txt (line 31)) (4.2.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\wwwsh\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r requirement.txt (line 31)) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\wwwsh\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->-r requirement.txt (line 31)) (0.4.8)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\wwwsh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard->-r requirement.txt (line 31)) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\wwwsh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard->-r requirement.txt (line 31)) (2.0.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\wwwsh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard->-r requirement.txt (line 31)) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\wwwsh\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard->-r requirement.txt (line 31)) (2021.10.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\wwwsh\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard->-r requirement.txt (line 31)) (3.2.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\wwwsh\anaconda3\lib\site-packages (from packaging->tensorflow->-r requirement.txt (line 32)) (3.0.4)
# Requirement already satisfied: pure-eval in c:\users\wwwsh\anaconda3\lib\site-packages (from stack-data->ipython->-r requirement.txt (line 9)) (0.2.2)
# Requirement already satisfied: asttokens in c:\users\wwwsh\anaconda3\lib\site-packages (from stack-data->ipython->-r requirement.txt (line 9)) (2.0.5)
# Requirement already satisfied: executing in c:\users\wwwsh\anaconda3\lib\site-packages (from stack-data->ipython->-r requirement.txt (line 9)) (0.8.3)

# %%
import tensorflow as tf
import numpy as np
import os
import glob
import pickle
import pyaudio
import time
from numpy import genfromtxt
from keras import backend as K
from keras.models import load_model
import sys
    
K.set_image_data_format('channels_first')
# np.set_printoptions(threshold=np.nan)
np.set_printoptions(threshold=sys.maxsize)

import pyaudio
from IPython.display import Audio, display, clear_output
import wave
from scipy.io.wavfile import read

from sklearn.mixture import GaussianMixture as GMM
# from sklearn.mixture import GMM 
# from sklearn import mixture

import warnings

warnings.filterwarnings("ignore")

from sklearn import preprocessing
# for converting audio to mfcc
import python_speech_features as mfcc

# %%
def calculate_delta(array):
    rows,cols = array.shape
    deltas = np.zeros((rows,20))
    N = 2
    for i in range(rows):
        index = []
        j = 1
        while j <= N:
            if i-j < 0:
                first = 0
            else:
                first = i-j
            if i+j > rows -1:
                second = rows -1
            else:
                second = i+j
            index.append((second,first))
            j+=1
        deltas[i] = ( array[index[0][0]]-array[index[0][1]] + (2 * (array[index[1][0]]-array[index[1][1]])) ) / 10
    return deltas

#convert audio to mfcc features
def extract_features(audio,rate):    
    mfcc_feat = mfcc.mfcc(audio,rate, 0.025, 0.01,20,appendEnergy = True, nfft=1103)
    mfcc_feat = preprocessing.scale(mfcc_feat)
    delta = calculate_delta(mfcc_feat)

    #combining both mfcc features and delta
    combined = np.hstack((mfcc_feat,delta)) 
    return combined

# %%
def add_user():
    
    name = input("Enter Name:")
     # check for existing database
    if os.path.exists('./voice_database/embeddings.pickle'):
        with open('./voice_database/embeddings.pickle', 'rb') as database:
            db = pickle.load(database)   
            
            if name in db:
                print("Name Already Exists! Try Another Name...")
                return
    else:
        #if database not exists than creating new database
        db = {}


    FORMAT = pyaudio.paInt16
    CHANNELS = 2
    RATE = 44100
    CHUNK = 1024
    RECORD_SECONDS = 3

    source = "./voice_database/" + name


    os.mkdir(source)

    for i in range(3):
        audio = pyaudio.PyAudio()

        if i == 0:
            j = 3
            while j>=0:
                time.sleep(1.0)
                print("Speak your name in {} seconds".format(j))
                clear_output(wait=True)

                j-=1

        elif i ==1:
            print("Speak your name one more time")
            time.sleep(0.5)

        else:
            print("Speak your name one last time")
            time.sleep(0.5)

        # start Recording
        stream = audio.open(format=FORMAT, channels=CHANNELS,
                    rate=RATE, input=True,
                    frames_per_buffer=CHUNK)

        print("recording...")
        frames = []

        for _ in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
            data = stream.read(CHUNK)
            frames.append(data)

        # stop Recording
        stream.stop_stream()
        stream.close()
        audio.terminate()

        # saving wav file of speaker
        waveFile = wave.open(source + '/' + str((i+1)) + '.wav', 'wb')
        waveFile.setnchannels(CHANNELS)
        waveFile.setsampwidth(audio.get_sample_size(FORMAT))
        waveFile.setframerate(RATE)
        waveFile.writeframes(b''.join(frames))
        waveFile.close()
        print("Done")

    dest =  "./gmm_models/"
    count = 1

    for path in os.listdir(source):
        path = os.path.join(source, path)

        features = np.array([])

        # reading audio files of speaker
        (sr, audio) = read(path)

        # extract 40 dimensional MFCC & delta MFCC features
        vector   = extract_features(audio,sr)

        if features.size == 0:
            features = vector
        else:
            features = np.vstack((features, vector))

        # when features of 3 files of speaker are concatenated, then do model training
        if count == 3:    
            gmm = GMM(n_components = 16, max_iter=200,covariance_type='diag',n_init = 3)
            gmm.fit(features)

            # saving the trained gaussian model
            pickle.dump(gmm, open(dest + name + '.GMM', 'wb'))
            print(name + ' added successfully') 

            features = np.asarray(())
            count = 0
        count = count + 1

if __name__ == '__main__':
    add_user()
# Out:
# recording...
# Done
# Speak your name one more time
# recording...
# Done
# Speak your name one last time
# recording...
# Done
# c added successfully

# %%
def recognize():
    # Voice Authentication
    FORMAT = pyaudio.paInt16
    CHANNELS = 2
    RATE = 44100
    CHUNK = 1024
    RECORD_SECONDS = 3
    FILENAME = "./test.wav"
    try:
        while True:
            audio = pyaudio.PyAudio()

            # start Recording
            stream = audio.open(format=FORMAT, channels=CHANNELS,
                            rate=RATE, input=True,
                            frames_per_buffer=CHUNK)

            print("recording...")
            frames = []

            for i in range(0, int(RATE / CHUNK * RECORD_SECONDS)):
                data = stream.read(CHUNK)
                frames.append(data)
            print("finished recording")


            # stop Recording
            stream.stop_stream()
            stream.close()
            audio.terminate()

            # saving wav file 
            waveFile = wave.open(FILENAME, 'wb')
            waveFile.setnchannels(CHANNELS)
            waveFile.setsampwidth(audio.get_sample_size(FORMAT))
            waveFile.setframerate(RATE)
            waveFile.writeframes(b''.join(frames))
            waveFile.close()

            modelpath = "./gmm_models/"

            gmm_files = [os.path.join(modelpath,fname) for fname in 
                        os.listdir(modelpath) if fname.endswith('.GMM')]

            models    = [pickle.load(open(fname,'rb')) for fname in gmm_files]

            speakers   = [fname.split("/")[-1].split(".GMM")[0] for fname 
                        in gmm_files]
            
            if len(models) == 0:
                print("No Users Authorized!")
                break
                
            #read test file
            sr,audio = read(FILENAME)

            # extract mfcc features
            vector = extract_features(audio,sr)
            log_likelihood = np.zeros(len(models)) 

            #checking with each model one by one
            for i in range(len(models)):
                gmm = models[i]         
                scores = np.array(gmm.score(vector))
                log_likelihood[i] = scores.sum()

            pred = np.argmax(log_likelihood)
            identity = speakers[pred]

            # if voice not recognized than terminate the process
            if identity == 'unknown':
                    print("Not Recognized! Try again...")
                    continue
            
            print( "Recognized as - ", identity)
    except KeyboardInterrupt:
        print("Stopped")
        pass

# %%
recognize()
# Out:
# recording...
# finished recording
# Recognized as -  c
# recording...
# finished recording
# Recognized as -  c
# recording...
# finished recording
# Recognized as -  c
# recording...
# finished recording
# Recognized as -  c
# recording...
# finished recording
# Recognized as -  c
# recording...
